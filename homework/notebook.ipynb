# %%
import os
    # import pandas as pd

# Descomprima el archivo
os.system('unzip -o ../files/input.zip -d ../files/')
# Out:
# 1

# %%
file = "../files/input/train/negative"

sentiment = file.split("/")[-1]

sentiment
# Out:
# 'negative'

# %%
a = os.listdir(file)
a
# Out:
# ['0000.txt',
#  '0001.txt',
#  '0002.txt',
#  '0003.txt',
#  '0004.txt',
#  '0005.txt',
#  '0006.txt',
#  '0007.txt',
#  '0008.txt',
#  '0009.txt',
#  '0010.txt',
#  '0011.txt',
#  '0012.txt',
#  '0013.txt',
#  '0014.txt',
#  '0015.txt',
#  '0016.txt',
#  '0017.txt',
#  '0018.txt',
#  '0019.txt',
#  '0020.txt',
#  '0021.txt',
#  '0022.txt',
#  '0023.txt',
#  '0024.txt',
#  '0025.txt',
#  '0026.txt',
#  '0027.txt',
#  '0028.txt',
#  '0029.txt',
#  '0030.txt',
#  '0031.txt',
#  '0032.txt',
#  '0033.txt',
#  '0034.txt',
#  '0035.txt',
#  '0036.txt',
#  '0037.txt',
#  '0038.txt',
#  '0039.txt',
#  '0040.txt',
#  '0041.txt',
#  '0042.txt',
#  '0043.txt',
#  '0044.txt',
#  '0045.txt',
#  '0046.txt',
#  '0047.txt',
#  '0048.txt',
#  '0049.txt',
#  '0050.txt',
#  '0051.txt',
#  '0052.txt',
#  '0053.txt',
#  '0054.txt',
#  '0055.txt',
#  '0056.txt',
#  '0057.txt',
#  '0058.txt',
#  '0059.txt',
#  '0060.txt',
#  '0061.txt',
#  '0062.txt',
#  '0063.txt',
#  '0064.txt',
#  '0065.txt',
# ...

# %%
"train" in file
# Out:
# True
